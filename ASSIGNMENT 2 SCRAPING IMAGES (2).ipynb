# %% [markdown]
# # Scrapping Men Jeans

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import os
import urllib
import urllib.request

browser=webdriver.Chrome("C:/Users/Karan/Desktop/chromedriver.exe")
browser.get('https://www.amazon.in/s?k=jeans+for+men&ref=nb_sb_noss_2')

# soup=BeautifulSoup(browser.page_source)
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=1000):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(1000,2000)
    
    full_name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
# Out:
# https://m.media-amazon.com/images/I/71Hh9bRtk2L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/51ZJ-qCJQfL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71U0hGZIibL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61iIbiC65uL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/812iG5h2AQL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61Don-d8JfL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81Nx4XaxG6L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81tK9MJ07rL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/618r4PBS73L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81beYvllyZL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81EhCxcqeiL._AC_UL320_.jpg
# loop break
# ...

# %% [markdown]
# # Scrapping saree Images

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import os
import urllib
import urllib.request

browser=webdriver.Chrome("C:/Users/Karan/Desktop/chromedriver.exe")
browser.get('https://www.amazon.in/s?k=sarees+for+women&crid=Z17H444BQ9RT&sprefix=sarees+for+women%2Caps%2C305&ref=nb_sb_ss_i_3_16')

# soup=BeautifulSoup(browser.page_source)
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=1000):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(2000,3000)
    
    full_name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
# Out:
# https://m.media-amazon.com/images/I/81Pm2QbSGXL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71rFoFwu6LL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71BnnQrR4cL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Otho+A39L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Gw2s5+5KL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81wCS9fycmL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71fJxSQVdIL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61b1twc91zL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81ujgS5lKqL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Pc9HRArSL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91UUm7luqiL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71lZhwh1ogL._AC_UL320_.jpg
# loop break
# ...

# %% [markdown]
# # Scrapping Trousers Images

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import os
import urllib
import urllib.request

browser=webdriver.Chrome("C:/Users/Karan/Desktop/chromedriver.exe")
browser.get('https://www.amazon.in/s?k=trousers+for+men&page=5')

# soup=BeautifulSoup(browser.page_source)
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=100):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(0,500)
    
    full_name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
       
# .get('src'),link.get_text()
# Out:
# https://m.media-amazon.com/images/I/7166MflwZdL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71Yqhczm3nL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81aLEvSqU+L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61Ahv4FNbIL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/51pS0HMeY7L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/717-fkXDpiL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81OIXQs8hxL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71OfJmRWIaL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71X12wEYawL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81f0kR2eyiL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81J9BMXuR8L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81YJzNYK4wL._AC_UL320_.jpg
# loop break
# ...
